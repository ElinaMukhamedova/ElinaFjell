# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 40, 41)
u1 = [0, 0.309017, 0.587785, 0.809017, 0.951057, 1, 0.951057, 0.809017, 0.587785, 0.309017, 1.22465e-16, -0.309017, -0.587785, -0.809017, -0.951057, -1, -0.951057, -0.809017, -0.587785, -0.309017, -2.44929e-16, 0.309017, 0.587785, 0.809017, 0.951057, 1, 0.951057, 0.809017, 0.587785, 0.309017, 3.67394e-16, -0.309017, -0.587785, -0.809017, -0.951057, -1, -0.951057, -0.809017, -0.587785, -0.309017, -4.89859e-16]
u2 = [0.0547723, -0.199818, -0.434849, -0.627314, -0.758374, -0.815198, -0.792225, -0.691703, -0.523473, -0.304002, -0.0547723, 0.199818, 0.434849, 0.627314, 0.758374, 0.815198, 0.792225, 0.691703, 0.523473, 0.304002, 0.0547723, -0.199818, -0.434849, -0.627314, -0.758374, -0.815198, -0.792225, -0.691703, -0.523473, -0.304002, -0.0547723, 0.199818, 0.434849, 0.627314, 0.758374, 0.815198, 0.792225, 0.691703, 0.523473, 0.304002, 0.0547723]
u3 = [-0.0893006, 0.119499, 0.316602, 0.482714, 0.601574, 0.661547, 0.656764, 0.587693, 0.461093, 0.289359, 0.0893006, -0.119499, -0.316602, -0.482714, -0.601574, -0.661547, -0.656764, -0.587693, -0.461093, -0.289359, -0.0893006, 0.119499, 0.316602, 0.482714, 0.601574, 0.661547, 0.656764, 0.587693, 0.461093, 0.289359, 0.0893006, -0.119499, -0.316602, -0.482714, -0.601574, -0.661547, -0.656764, -0.587693, -0.461093, -0.289359, -0.0893006]
u4 = [0.00690925, -0.163972, -0.318802, -0.442426, -0.522742, -0.551889, -0.527012, -0.450548, -0.329982, -0.177114, -0.00690925, 0.163972, 0.318802, 0.442426, 0.522742, 0.551889, 0.527012, 0.450548, 0.329982, 0.177114, 0.00690925, -0.163972, -0.318802, -0.442426, -0.522742, -0.551889, -0.527012, -0.450548, -0.329982, -0.177114, -0.00690925, 0.163972, 0.318802, 0.442426, 0.522742, 0.551889, 0.527012, 0.450548, 0.329982, 0.177114, 0.00690925]
u5 = [0.463761, 0.49002, 0.468311, 0.400761, 0.293982, 0.158426, 0.00736181, -0.144423, -0.282071, -0.392107, -0.463761, -0.49002, -0.468311, -0.400761, -0.293982, -0.158426, -0.00736181, 0.144423, 0.282071, 0.392107, 0.463761, 0.49002, 0.468311, 0.400761, 0.293982, 0.158426, 0.00736181, -0.144423, -0.282071, -0.392107, -0.463761, -0.49002, -0.468311, -0.400761, -0.293982, -0.158426, -0.00736181, 0.144423, 0.282071, 0.392107, 0.463761]
plt.grid()
plt.plot(x, u1, label = "t = 0")
plt.plot(x, u2, label = "t = 5")
plt.plot(x, u3, label = "t = 10")
plt.plot(x, u4, label = "t = 15")
plt.plot(x, u5, label = "t = 18")
plt.xlabel(r'x', loc = 'center')
plt.ylabel(r'u', rotation = 90, loc = 'center')
plt.title("Courant number = 0.6")
plt.legend()
plt.savefig("results/TransportEquationUpwindGraph_1.jpg")
plt.show()

# %%
x = np.linspace(0, 40, 41)
u1 = [0, 0.309017, 0.587785, 0.809017, 0.951057, 1, 0.951057, 0.809017, 0.587785, 0.309017, 1.22465e-16, -0.309017, -0.587785, -0.809017, -0.951057, -1, -0.951057, -0.809017, -0.587785, -0.309017, -2.44929e-16, 0.309017, 0.587785, 0.809017, 0.951057, 1, 0.951057, 0.809017, 0.587785, 0.309017, 3.67394e-16, -0.309017, -0.587785, -0.809017, -0.951057, -1, -0.951057, -0.809017, -0.587785, -0.309017, -4.89859e-16]
u2 = [3.67394e-16, -0.309017, -0.587785, -0.809017, -0.951057, -1, -0.951057, -0.809017, -0.587785, -0.309017, 0, 0.309017, 0.587785, 0.809017, 0.951057, 1, 0.951057, 0.809017, 0.587785, 0.309017, 1.22465e-16, -0.309017, -0.587785, -0.809017, -0.951057, -1, -0.951057, -0.809017, -0.587785, -0.309017, -2.44929e-16, 0.309017, 0.587785, 0.809017, 0.951057, 1, 0.951057, 0.809017, 0.587785, 0.309017, 3.67394e-16]
u3 = [-2.44929e-16, 0.309017, 0.587785, 0.809017, 0.951057, 1, 0.951057, 0.809017, 0.587785, 0.309017, 3.67394e-16, -0.309017, -0.587785, -0.809017, -0.951057, -1, -0.951057, -0.809017, -0.587785, -0.309017, 0, 0.309017, 0.587785, 0.809017, 0.951057, 1, 0.951057, 0.809017, 0.587785, 0.309017, 1.22465e-16, -0.309017, -0.587785, -0.809017, -0.951057, -1, -0.951057, -0.809017, -0.587785, -0.309017, -2.44929e-16]
u4 = [1.22465e-16, -0.309017, -0.587785, -0.809017, -0.951057, -1, -0.951057, -0.809017, -0.587785, -0.309017, -2.44929e-16, 0.309017, 0.587785, 0.809017, 0.951057, 1, 0.951057, 0.809017, 0.587785, 0.309017, 3.67394e-16, -0.309017, -0.587785, -0.809017, -0.951057, -1, -0.951057, -0.809017, -0.587785, -0.309017, 0, 0.309017, 0.587785, 0.809017, 0.951057, 1, 0.951057, 0.809017, 0.587785, 0.309017, 1.22465e-16]
u5 = [0.951057, 1, 0.951057, 0.809017, 0.587785, 0.309017, 1.22465e-16, -0.309017, -0.587785, -0.809017, -0.951057, -1, -0.951057, -0.809017, -0.587785, -0.309017, -2.44929e-16, 0.309017, 0.587785, 0.809017, 0.951057, 1, 0.951057, 0.809017, 0.587785, 0.309017, 3.67394e-16, -0.309017, -0.587785, -0.809017, -0.951057, -1, -0.951057, -0.809017, -0.587785, -0.309017, 0, 0.309017, 0.587785, 0.809017, 0.951057]
plt.grid()
plt.plot(x, u1, label = "t = 0")
plt.plot(x, u2, label = "t = 5")
plt.plot(x, u3, label = "t = 10")
plt.plot(x, u4, label = "t = 15")
plt.plot(x, u5, label = "t = 18")
plt.xlabel(r'x', loc = 'center')
plt.ylabel(r'u', rotation = 90, loc = 'center')
plt.title("Courant number = 1")
plt.legend()
plt.savefig("results/TransportEquationUpwindGraph_2.jpg")
plt.show()
